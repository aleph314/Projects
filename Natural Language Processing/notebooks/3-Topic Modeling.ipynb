# %% [markdown]
# # IT Tickets Classification Project

# %% [markdown]
# ## Previous Notebooks
#
# - [Data Collection](0-Data Collection.ipynb)
# - [Data Cleaning and EDA](1-Data Cleaning and EDA.ipynb)
# - [Document-Term Matrix](2-Document-Term Matrix.ipynb)

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse.linalg import svds

# %% [markdown]
# ## Topic Modeling

# %% [markdown]
# In this notebook I use SVD to do topic modeling of the tickets' text, selecting the first 20 eigenvectors to represent the 20 most relevant topics in the collection. Before applying SVD I normalize the document-term matrix using TF-IDF.

# %%
doc_term = pd.read_pickle('../data/interim/document_term.pkl')

# %%
tfidf = TfidfTransformer()
X = tfidf.fit_transform(doc_term)

# %%
k = 20
u, s, vt = svds(X, k=k)

# %%
s
# Out:
# array([ 10.48890729,  10.695562  ,  10.88343826,  11.62480531,
#         11.94193887,  11.96500652,  12.72272519,  13.15786524,
#         13.66620399,  14.02286417,  14.15552572,  15.24216734,
#         16.09869209,  17.74408135,  18.18617037,  19.91073291,
#         21.9617521 ,  24.93779523,  28.14551286,  33.79456837])

# %% [markdown]
# Below are the 10 most relevant keywords of the selected topics: topic 20 seems to be related to some technical terms, while the other topics seem to be related to agreements (e.g. topic 16, 15 and 8), suppliers (e.g. topic 19, 18 and 11) or IT procedures (e.g. topic 12 and 11).

# %%
topics = []
for i in range(k):
    topics.append(list(pd.Series(vt[i], index=doc_term.columns).sort_values(ascending=False).head(10).index.values))

topics = pd.DataFrame(topics)
topics.columns = ['word{}'.format(i+1) for i in topics.columns.values]
topics.sort_index(ascending=False, inplace=True)
topics.index = ['topic{}'.format(i+1) for i in topics.index.values]
topics.T.iloc[:, 0:10]
# Out:
#                                          topic20     topic19     topic18  \
# word1   managedreferencemethodinterceptorfactory        octo         box
# word2          managedreferencemethodinterceptor         box       attiv
# word3                         initialinterceptor      ticket    terminal
# word4             componentdispatcherinterceptor       fluss     conferm
# word5                 isadocbusinessdelegateimpl  disinstall      portal
# word6                          isadocproxyclient    terminal        forz
# word7                          weavedinterceptor       attiv  disinstall
# word8                     userinterceptorfactory      portal       smont
# word9                                      jaxws        forz        stat
# word10                           synchronization     conferm  telematics
#
#          topic17   topic16   topic15    topic14  topic13    topic12    topic11
# word1        dat  copertur     smart       graz  recuper        fil  riapertur
# word2       stat   recuper   disdett     sospes   sospes      alleg       octo
# word3     append      graz       car      alleg    verif     import        atr
# word4        pag    incass  retroatt    recuper     manc     elabor    voucher
# word5       prem    import  contratt        cia    alleg  produzion    aggiorn
# word6        eur       cia    recess  buongiorn      fil   procedur      fluss
# word7   copertur     verif    client        fil     accm       lanc     covell
# word8      regol     alleg    intest      chied     esit       esit        pol
# word9       graz   richied  disposit       targ   elabor     sospes       scad
# word10   martell       box   verific  produzion   covell      titol      lavor

# %%
topics.T.iloc[:, 10:20]
# Out:
#           topic10  topic9      topic8      topic7   topic6      topic5  \
# word1        lanc     atr  convenzion  convenzion  riattiv     riattiv
# word2    procedur   caric   dipendent   dipendent  visibil        targ
# word3   produzion    buon       verif       inser  potrest        graz
# word4         fil   lavor        manc   migrazion   client     propost
# word5      elabor     ani       inser         dat  verific  convenzion
# word6       ebaas   chied         atr       ebaas     targ         cia
# word7       input     pol      incass        abit   oggett   dipendent
# word8         dat    scad     sostitu      famigl     iban      rinnov
# word9        esit  rinnov      elabor     scadenz     manc     richied
# word10       batc     cia        lanc     anagraf   covell      finocc
#
#             topic4     topic3     topic2     topic1
# word1      riattiv      error    anagraf    sinistr
# word2       covell      alleg    trasfer     elabor
# word3          atr    sinistr     script    trasfer
# word4        utenz        pag      esecu        fil
# word5          pol        fas  produzion    anagraf
# word6        caric        sin     covell     oggett
# word7   convenzion     serviz    ambient       esit
# word8    contraent     dispon      esegu     liquid
# word9       abilit  buongiorn        dat  estrazion
# word10     visibil       stat    sinistr     cortes

# %%
issues = pd.read_pickle('../data/interim/bag_of_words.pkl')

# %% [markdown]
# Finally I'm going to create the dataset I will use to predict the topics' labels by adding to the topic data the label and issue type:

# %%
processed_data = pd.DataFrame(u, index=issues['key'])
processed_data.columns = ['topic{}'.format(i+1) for i in processed_data.columns.values]
processed_data = processed_data.merge(issues[['key', 'issue_type', 'label']].set_index('key'),
                                      how='inner', left_index=True, right_index=True)

# %%
processed_data.head()
# Out:
#                topic1    topic2    topic3    topic4    topic5    topic6  \
# key
# ISAHD-31941 -0.009479 -0.003791  0.017397 -0.002119 -0.011360  0.004534
# ISAHD-31940  0.003563  0.003421 -0.000765  0.002659 -0.004842 -0.000941
# ISAHD-31939 -0.010522 -0.003833  0.010525 -0.004286 -0.014718  0.007967
# ISAHD-31938 -0.007514 -0.002789  0.011523 -0.002412 -0.014195  0.006187
# ISAHD-31937 -0.003378 -0.004804 -0.008330 -0.006930  0.001492  0.002304
#
#                topic7    topic8    topic9   topic10          ...           \
# key                                                          ...
# ISAHD-31941 -0.004413  0.001417 -0.010153 -0.001711          ...
# ISAHD-31940 -0.001263  0.000591  0.004206 -0.000204          ...
# ISAHD-31939 -0.006912 -0.000352 -0.007102 -0.000095          ...
# ISAHD-31938 -0.006845 -0.000117 -0.009371 -0.000022          ...
# ISAHD-31937 -0.001676  0.000079 -0.003020 -0.001176          ...
#
#               topic13   topic14   topic15   topic16   topic17   topic18  \
# key
# ISAHD-31941 -0.003778  0.004760  0.000375  0.002743  0.003082 -0.000670
# ISAHD-31940 -0.003044  0.001408  0.000027  0.001142  0.001050 -0.000507
# ISAHD-31939 -0.003860  0.004374  0.000327  0.001815  0.002870  0.000539
# ISAHD-31938 -0.001613  0.005189  0.000371  0.002673  0.003931 -0.000812
# ISAHD-31937 -0.004654  0.002205  0.000179  0.003854 -0.002536 -0.007580
#
#               topic19   topic20     issue_type                 label
# key
# ISAHD-31941 -0.000691 -0.000491  Modifica dati        ISAHD Rilascio
# ISAHD-31940 -0.000266 -0.000249  Modifica dati  ISAHD Forzatura dati
# ISAHD-31939 -0.003514 -0.002006  Modifica dati           ISAHD Altro
# ISAHD-31938 -0.000766 -0.000688  Modifica dati        ISAHD Rilascio
# ISAHD-31937  0.001632 -0.010511  Modifica dati  ISAHD Forzatura dati
#
# [5 rows x 22 columns]

# %%
processed_data.to_pickle('../data/processed/proc_data.pkl')

# %% [markdown]
# ## Following Notebooks
#
# - [Random Forest Prediction](4-Model.ipynb)
